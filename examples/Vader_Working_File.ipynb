# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/yash/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sia = SentimentIntensityAnalyzer()

# %%
df = pd.read_csv('Reddit_Test.csv')

# %%
VAR = 0.05

# %%
df['Negative'] = df['Comment'].apply(lambda x:sia.polarity_scores(str(x))['neg'])
df['Neutral'] = df['Comment'].apply(lambda x:sia.polarity_scores(str(x))['neu'])
df['Positive'] = df['Comment'].apply(lambda x:sia.polarity_scores(str(x))['pos'])
df['Compound'] = df['Comment'].apply(lambda x:sia.polarity_scores(str(x))['compound'])

# %%
df['Weighted_Sentiment_Neg'] = df.apply(lambda row: (row['Negative']*row['Compound']
                                                    if row['Compound'] > 0 or row['Compound'] < 0
                                                    else row['Negative'] * VAR 
                                                 ), axis=1)
df['Weighted_Sentiment_Neu'] = df.apply(lambda row: (row['Neutral']*row['Compound']
                                                    if row['Compound'] > 0 or row['Compound'] < 0
                                                    else row['Neutral'] * VAR 
                                                 ), axis=1)
df['Weighted_Sentiment_Pos'] = df.apply(lambda row: (row['Positive']*row['Compound']
                                                    if row['Compound'] > 0 or row['Compound'] < 0
                                                    else row['Positive'] * VAR 
                                                 ), axis=1)

# %%
df['Sum_Weights'] = df.apply(lambda row: (row['Weighted_Sentiment_Neg'] + row['Weighted_Sentiment_Neu']
                                         + row['Weighted_Sentiment_Pos']), axis=1)

# %%
df
# Out:
#       Unnamed: 0        Date  \
# 0              0  12/01/2021
# 1              1  11/30/2021
# 2              2  11/30/2021
# 3              3  11/30/2021
# 4              4  11/30/2021
# ...          ...         ...
# 6143         145  10/21/2021
# 6144         146  10/20/2021
# 6145         147  10/20/2021
# 6146         148  10/20/2021
# 6147         149  10/20/2021
#
#                                                 Comment     Tags  \
# 0                             $OPTT Sea you on the moon    $OPTT
# 1                      $OPTT full circle. It’s time 🔔🔔🔔    $OPTT
# 2     The one time I buy $AMC it just pissed my mone...     $AMC
# 3                                                 $RDBX    $RDBX
# 4     Watch me either make a lot of money or lose a ...    $PYPL
# ...                                                 ...      ...
# 6143  Views on $AGD vs. $QYLD? Is one less risky? Re...    $QYLD
# 6144                $$$$ Leader in Green! Assets (LIGA)        $
# 6145            $$***Leader in Green***$$ &gt;&gt; LIGA  $LEADER
# 6146  The Future Of Game Asset Exchange| The greates...     $EXP
# 6147  The Future Of Game Asset Exchange| The coolest...     $EXP
#
#            Subreddit  Negative  Neutral  Positive  Compound  \
# 0     wallstreetbets     0.000    1.000     0.000    0.0000
# 1     wallstreetbets     0.000    1.000     0.000    0.0000
# 2     wallstreetbets     0.296    0.704     0.000   -0.6369
# 3     wallstreetbets     0.000    1.000     0.000    0.0000
# 4     wallstreetbets     0.119    0.881     0.000   -0.4019
# ...              ...       ...      ...       ...       ...
# 6143       investing     0.185    0.815     0.000   -0.2610
# 6144       investing     0.000    0.715     0.285    0.2481
# 6145       investing     0.000    1.000     0.000    0.0000
# 6146       investing     0.000    0.642     0.358    0.7717
# 6147       investing     0.000    0.839     0.161    0.3612
#
#       Weighted_Sentiment_Neg  Weighted_Sentiment_Neu  Weighted_Sentiment_Pos  \
# 0                   0.000000                0.050000                0.000000
# 1                   0.000000                0.050000                0.000000
# 2                  -0.188522               -0.448378               -0.000000
# 3                   0.000000                0.050000                0.000000
# 4                  -0.047826               -0.354074               -0.000000
# ...                      ...                     ...                     ...
# 6143               -0.048285               -0.212715               -0.000000
# 6144                0.000000                0.177391                0.070708
# 6145                0.000000                0.050000                0.000000
# 6146                0.000000                0.495431                0.276269
# 6147                0.000000                0.303047                0.058153
#
#       Sum_Weights
# 0          0.0500
# 1          0.0500
# 2         -0.6369
# 3          0.0500
# 4         -0.4019
# ...           ...
# 6143      -0.2610
# 6144       0.2481
# 6145       0.0500
# 6146       0.7717
# 6147       0.3612
#
# [6148 rows x 13 columns]

# %%
def
